'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ee7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ef4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ef6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ef8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ef9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9efa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9efb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9efc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f06'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f0f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f10'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f12'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f1e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f1f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f20'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f23'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f2a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f2c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f3c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f44'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f4a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f4f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f54'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f58'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f60'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f66'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f67'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f69'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f6d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f6f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f70'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f76'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f7a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f93'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9f9c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fa5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fa9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fb0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fb6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fb9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fd2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fd8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fd9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fe5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9fe8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ff2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ff5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ff6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ff7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ff9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ffa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bd9ffe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda002'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda00a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda00b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda011'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda012'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda017'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda019'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda01c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda023'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda024'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda025'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda029'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda02f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda032'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda038'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda039'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50bda03a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'_id': ObjectId('65079436b347c51b50be2fd9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fda'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fdd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fe1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fe2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fe3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fe6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fe7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2feb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fee'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2fef'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2ff0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be2ffc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3001'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3005'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3006'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be300b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be300c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be300d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be300e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be300f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3010'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3012'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3013'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3017'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3019'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be301a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be301b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be301e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3020'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3021'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3022'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3027'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be302d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be302f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3030'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3031'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3032'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3033'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3035'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be303a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be303b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3040'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3047'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3048'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be304d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be304f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be305a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be305c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be305d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3061'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be306d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3089'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3092'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3097'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3099'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be309c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be309e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be309f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30a0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30a1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30a6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30bc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30cf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30dc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30df'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30e2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30ea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30ee'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be30f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3109'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be310a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3114'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3116'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be311c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3121'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3126'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be312a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be312b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3134'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3138'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3139'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be313c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3142'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3146'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3147'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3149'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be314a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be314b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be314d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be314e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be314f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3153'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3156'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3157'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3158'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be315b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be315c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be315e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3160'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3162'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3163'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3164'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3165'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3169'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be316b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be316e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3172'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3174'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3176'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3178'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3179'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be317e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3182'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3189'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be318a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be3195'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be319a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be319c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31a4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31bf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31c3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31d1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31d3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31d8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31da'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31ea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079436b347c51b50be31f4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('65079e8aa85f97ff040c0511'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
    {"BusinessName":"Penang Flavours"},
    {'$set':
        {'BusinessTypeID':1}
    }
)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
fields = {"BusinessTypeID":1}
results = establishments.find(query, fields)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('65079e8aa85f97ff040c0511'), 'BusinessTypeID': 1}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName':'Dover'}
print("Number of documents in Dover:", establishments.count_documents(query))
# Out:
# Number of documents in Dover: 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
db.establishments.delete_many({"LocalAuthorityName":"Dover"})

# %%
# Check if any remaining documents include Dover
print("Number of documents in Dover:", establishments.count_documents(query))
# Out:
# Number of documents in Dover: 0

# %%
# Check that other documents remain with 'find_one'
db.establishments.find_one()
# Out:
# {'_id': ObjectId('65079435b347c51b50bd9967'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# ##Use `update_many` to convert `latitude` and `longitude` to decimal numbers.##

# %%
# Change the data type from String to Decimal for longitude and latitude
db.establishments.update_many({}, [
    {
        '$set': {
            "geocode.longitude" : {'$toDouble': "$geocode.longitude"},
            "geocode.latitude" : {'$toDouble': "$geocode.latitude"}
            }
            }
])

# %% [markdown]
# ##Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
db.establishments.update_many({}, [
    {
        '$set': {
            "RatingValue" : {'$toInt': "$RatingValue"}
        }
    }
])

# %%
# Check that the coordinates and rating value are now numbers
x = type(establishments.find_one()["geocode"]["longitude"])
y = type(establishments.find_one()["geocode"]["longitude"])
z = type(establishments.find_one()["RatingValue"])
print(x, y, z)
# Out:
# <class 'float'> <class 'float'> <class 'int'>
